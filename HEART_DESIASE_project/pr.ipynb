# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
#  ## Data Understanding

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
df['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 723

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # EDA [Explorotry data analysis]

# %%
sns.histplot(df['age'])
plt.show()

# %% [markdown]
# heart desase by the gender
#
# 0-female
# 1-male
#
# target :
#     1-yes desiase
#     ,0-no desiase

# %%
sns.countplot(x='sex',hue='target',data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
x=df.drop("target",axis=1)
y=df['target']

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# ## Model traing

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(random_state=42)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## Evaluate

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
y_pred=model.predict(X_test)

# %%
print("accuracy_score is :",accuracy_score(y_test,y_pred)*100)
# Out:
# accuracy_score is : 97.07792207792207

# %%
print("classification_report is :",classification_report(y_test,y_pred))
# Out:
# classification_report is :               precision    recall  f1-score   support
#
#            0       0.78      0.73      0.75        48
#            1       0.72      0.77      0.74        43
#
#     accuracy                           0.75        91
#    macro avg       0.75      0.75      0.75        91
# weighted avg       0.75      0.75      0.75        91

# %% [markdown]
# # Visulizing the tree

# %%
from sklearn import tree
plt.Figure(figsize=(20,15))
tree.plot_tree(model,filled=True)
plt.show()

# %% [markdown]
# ## Analyszing that which factore affects the desises

# %%
importance = pd.Series(
    model.feature_importances_,
    index=x.columns
)

# %%
importance.sort_values().plot(kind="barh")
plt.show()

# %% [markdown]
# # Hyper parameter tunig

# %%
param = {
    'criterion': ['gini', 'entropy', 'log_loss'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 1, 2, 3, 4, 5, 10, 15, 20, 25],
    'max_features': [None, 'sqrt', 'log2'],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid=GridSearchCV(model,param_grid=param,cv=5)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [None, 1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 10,
#  'splitter': 'random'}

# %%
y_pred=grid.predict(X_test)

# %%
print("accuracy_score is : ",accuracy_score(y_test,y_pred)*100)
# Out:
# accuracy_score is :  97.07792207792207

# %%
print("classification report is: ",classification_report(y_test,y_pred))
# Out:
# classification report is:                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       159
#            1       1.00      0.94      0.97       149
#
#     accuracy                           0.97       308
#    macro avg       0.97      0.97      0.97       308
# weighted avg       0.97      0.97      0.97       308

# %%
selected_model=DecisionTreeClassifier(criterion= 'entropy',
 max_depth= None,
 max_features= 'sqrt',
 min_samples_leaf= 1,
 min_samples_split= 10,
 splitter= 'random')

# %%
selected_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        min_samples_split=10, splitter='random')

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(selected_model,filled=True)
plt.show()

# %% [markdown]
# # After Hyper parameter tuning which parametrs or columns affets the mostfor the desise

# %%
importance = pd.Series(
    selected_model.feature_importances_,
    index=x.columns
)

# %%
importance.sort_values().plot(kind="barh")
plt.show()

# %% [markdown]
# ## overfitting checking of the model

# %%
print("Model accuracy is on train data :",selected_model.score(X_train,y_train)*100)
print("Model accuracy is on test data :",selected_model.score(X_test,y_test)*100)
# Out:
# Model accuracy is on train data : 85.30805687203792
# Model accuracy is on test data : 78.02197802197803

# %% [markdown]
# ## Comaparing with the other models also for the evluation

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=1000)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
print("Logistic Accuracy:", lr.score(X_test, y_test))
print("Decision Tree Accuracy:", model.score(X_test, y_test))
print("Decision tree accuracy after hyperparametr tuning :",selected_model.score(X_test,y_test))
# Out:
# Logistic Accuracy: 0.8051948051948052
# Decision Tree Accuracy: 0.9707792207792207
# Decision tree accuracy after hyperparametr tuning : 0.8798701298701299

# %% [markdown]
# ## ON comaparing with the Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

print("Random Forest Accuracy:", rf.score(X_test, y_test)*100)
# Out:
# Random Forest Accuracy: 98.05194805194806

# %% [markdown]
# ## Comparing the all the models at time

# %% [markdown]
# model got overriten so i did like this we can direclty make dictonry and use it

# %%
dt_before = DecisionTreeClassifier(random_state=42)
dt_before.fit(X_train, y_train)

dt_after = selected_model   # your tuned model

lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
models = {
    "Decision Tree (Before Tuning)": dt_before.score(X_test, y_test),
    "Decision Tree (After Tuning)": dt_after.score(X_test, y_test),
    "Logistic Regression": lr.score(X_test, y_test),
    "Random Forest": rf.score(X_test, y_test)
}

for name, score in models.items():
    print(name, ":", score*100)
# Out:
# Decision Tree (Before Tuning) : 74.72527472527473
# Decision Tree (After Tuning) : 78.02197802197803
# Logistic Regression : 83.51648351648352
# Random Forest : 81.31868131868131

# %% [markdown]
# ## ROC curve for the Descion tree model

# %%
from sklearn.metrics import roc_auc_score,roc_curve,auc

# %%
y_prob=selected_model.predict_proba(X_test)[:, 1]

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
plt.plot(fpr, tpr, label="Descion tree (AUC = %0.2f)" % roc_auc)
plt.plot([0,1], [0,1], 'r--')  # random line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# ## for all model roc curve

# %%
models = {
    "Logistic": lr,
    "Decision Tree": model,
    "Random Forest": rf
}

plt.figure()

for name, model in models.items():
    y_prob = model.predict_proba(X_test)[:,1]
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{name} (AUC={roc_auc:.2f})")

plt.plot([0,1], [0,1], 'r--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.show()

# %% [markdown]
# After comparing multiple models including Decision Tree, Random Forest, and Logistic Regression, Logistic Regression achieved the highest accuracy (83.5%) and AUC score (0.85). Therefore, it was selected as the final model for heart disease prediction.

# %%
import pickle

pickle.dump(lr, open("heart_disease_model.pkl", "wb"))

# %%
import pandas as pd

results = {
    "Model": ["Decision Tree", "Decision Tree Tuned", "Random Forest", "Logistic Regression"],
    "Accuracy": [0.747, 0.780, 0.813, 0.835]
}

results_df = pd.DataFrame(results)
results_df
# Out:
#                  Model  Accuracy
# 0        Decision Tree     0.747
# 1  Decision Tree Tuned     0.780
# 2        Random Forest     0.813
# 3  Logistic Regression     0.835

# %% [markdown]
# ## Example input from the paitent

# %%
# Example patient
input_data = np.array([[52, 1, 0, 125, 212,
                        0, 1, 168,
                        0, 1.0, 2,
                        2, 3]])

# %%
prediction = model.predict(input_data)

if prediction[0] == 1:
    print("⚠ Patient has heart disease")
else:
    print(" Patient does NOT have heart disease")
# Out:
# ✅ Patient does NOT have heart disease

# %%
# probablity of having the desease

# %%
prdict=model.predict_proba(input_data)
print("Probablity of having disese is :",prdict[0][1]*100)
# Out:
# Probablity of having disese is : 1.0

# %%
# According to the Logistic regresion the probablity of having Disease
prob = lr.predict_proba(input_data)

print("Probability of Heart Disease:", prob[0][1]*100)
# Out:
# Probability of Heart Disease: 22.379998515614943

# %%
# According to the Hyper tuned model of discion tree the probablity of having Disease
prob = selected_model.predict_proba(input_data)

print("Probability of Heart Disease:", prob[0][1]*100)
# Out:
# Probability of Heart Disease: 33.33333333333333

# %%
# According to the Random forest the probablity of having Disease
prob = rf.predict_proba(input_data)

print("Probability of Heart Disease:", prob[0][1]*100)
# Out:
# Probability of Heart Disease: 1.0
